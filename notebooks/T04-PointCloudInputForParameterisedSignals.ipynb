# %%
import glob
import os
basename = "/global/cfs/projectdirs/m3246/AnomalyDetection/ILC/Delphes-3.5.0/LHCO_RnD_qq"
files = glob.glob(os.path.join(basename, "*qq_*_*.txt"))
outdir = "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/"

# %%
import numpy as np
import awkward as ak
from aliad.interface.awkward import Momentum4DArrayBuilder
from pyjet import DTYPE_PTEPM
from quickstats.utils.string_utils import split_str

def parse_RnD_qq_txt_file(filename:str, sort_by_mass:bool=True):
    event_numbers = []
    jet_indices = []
    jet_features = []
    part_features = []
    with open(filename, 'r') as f:
        data = f.readlines()
    for line in data:
        tokens = line.split()
        event_number = int(tokens[0])
        jet_index = int(tokens[1])
        jet_features_i = [float(token) for token in tokens[3:13]]
        part_features_i = [tuple(split_str(tokens, cast=float) + [0.]) \
                           for tokens in line.split('P')[1:]]
        part_features_i = np.array(part_features_i, dtype=[("pT", "float64"),
                                                           ("eta", "float64"),
                                                           ("phi", "float64"),
                                                           ("mass", "float64")])
        event_numbers.append(event_number)
        jet_indices.append(jet_index)        
        jet_features.append(jet_features_i)
        part_features.append(part_features_i)
    event_numbers = np.array(event_numbers)
    jet_indices = np.array(jet_indices)
    jet_size = np.unique(jet_indices).shape[0]
    jet_features = np.array(jet_features)
    array_builder = Momentum4DArrayBuilder('PtEtaPhiM')
    part_features = array_builder.get_array_from_list(part_features)
    record = {
        'event_number'  : event_numbers,
        'jet_index'     : jet_indices,
        'jet_features'  : jet_features,
        'part_features' : part_features
    }
    if sort_by_mass:
        sample_size = jet_features.shape[0]
        sort_idx = np.argsort(-jet_features[:, 3].reshape(sample_size//jet_size, jet_size), axis=-1)
        sort_idx = sort_idx + np.arange(sample_size//jet_size).reshape(sample_size//jet_size, 1) * jet_size
        sort_idx = sort_idx.flatten()
        for key in ['jet_features', 'part_features']:
            record[key] = record[key][sort_idx]
    record = ak.Record(record)
    return record

# %%
data = {}
save = True
cache = True
for filename in files:
    tokens = os.path.splitext(os.path.basename(filename))[0].split("_")
    m1, m2 = tokens[-2], tokens[-1]
    basename = os.path.basename(filename)
    outname = os.path.join(outdir, "row_based", f"point_cloud_W_qq_{m1}_{m2}.parquet")
    print(f'INFO: Working on m1 = {m1}, m2 = {m2}')
    if (not cache) or (not os.path.exists(outname)):
        print(f'INFO: Parsing file "{basename}"')
        data[f"{m1}_{m2}"] = parse_RnD_qq_txt_file(filename)
        if save:
            print(f'INFO: Saving output to "{outname}"')
            ak.to_parquet(data[f"{m1}_{m2}"], outname)
    else:
        print(f'INFO: Cached output from "{outname}"')
        data[f"{m1}_{m2}"] = ak.from_parquet(outname)
# Out:
# INFO: Working on m1 = 100, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_100_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_500.parquet"
# INFO: Working on m1 = 300, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_300_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_100.parquet"
# INFO: Working on m1 = 350, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_350_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_350.parquet"
# INFO: Working on m1 = 400, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_400_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_400.parquet"
# INFO: Working on m1 = 250, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_250_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_50.parquet"
# INFO: Working on m1 = 500, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_500_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_400.parquet"
# INFO: Working on m1 = 350, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_350_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_300.parquet"
# INFO: Working on m1 = 400, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_400_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_50.parquet"
# INFO: Working on m1 = 250, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_250_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_550.parquet"
# INFO: Working on m1 = 600, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_600_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_300.parquet"
# INFO: Working on m1 = 50, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_50_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_100.parquet"
# INFO: Working on m1 = 200, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_200_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_150.parquet"
# INFO: Working on m1 = 200, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_200_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_550.parquet"
# INFO: Working on m1 = 500, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_500_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_500.parquet"
# INFO: Working on m1 = 550, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_550_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_300.parquet"
# INFO: Working on m1 = 200, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_200_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_300.parquet"
# INFO: Working on m1 = 200, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_200_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_600.parquet"
# INFO: Working on m1 = 450, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_450_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_100.parquet"
# INFO: Working on m1 = 200, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_200_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_400.parquet"
# INFO: Working on m1 = 350, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_350_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_250.parquet"
# INFO: Working on m1 = 600, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_600_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_200.parquet"
# INFO: Working on m1 = 250, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_250_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_250.parquet"
# INFO: Working on m1 = 550, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_550_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_500.parquet"
# INFO: Working on m1 = 200, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_200_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_100.parquet"
# INFO: Working on m1 = 250, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_250_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_600.parquet"
# INFO: Working on m1 = 150, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_150_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_150.parquet"
# INFO: Working on m1 = 550, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_550_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_250.parquet"
# INFO: Working on m1 = 250, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_250_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_500.parquet"
# INFO: Working on m1 = 500, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_500_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_250.parquet"
# INFO: Working on m1 = 250, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_250_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_400.parquet"
# INFO: Working on m1 = 150, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_150_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_100.parquet"
# INFO: Working on m1 = 150, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_150_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_300.parquet"
# INFO: Working on m1 = 50, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_50_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_200.parquet"
# INFO: Working on m1 = 50, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_50_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_500.parquet"
# INFO: Working on m1 = 300, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_300_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_250.parquet"
# INFO: Working on m1 = 450, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_450_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_50.parquet"
# INFO: Working on m1 = 300, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_300_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_500.parquet"
# INFO: Working on m1 = 600, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_600_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_350.parquet"
# INFO: Working on m1 = 450, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_450_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_200.parquet"
# INFO: Working on m1 = 300, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_300_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_600.parquet"
# INFO: Working on m1 = 100, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_100_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_200.parquet"
# INFO: Working on m1 = 400, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_400_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_550.parquet"
# INFO: Working on m1 = 100, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_100_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_450.parquet"
# INFO: Working on m1 = 500, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_500_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_200.parquet"
# INFO: Working on m1 = 150, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_150_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_450.parquet"
# INFO: Working on m1 = 250, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_250_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_350.parquet"
# INFO: Working on m1 = 500, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_500_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_50.parquet"
# INFO: Working on m1 = 400, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_400_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_350.parquet"
# INFO: Working on m1 = 400, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_400_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_250.parquet"
# INFO: Working on m1 = 250, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_250_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_450.parquet"
# INFO: Working on m1 = 350, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_350_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_400.parquet"
# INFO: Working on m1 = 50, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_50_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_550.parquet"
# INFO: Working on m1 = 200, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_200_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_450.parquet"
# INFO: Working on m1 = 150, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_150_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_600.parquet"
# INFO: Working on m1 = 450, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_450_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_300.parquet"
# INFO: Working on m1 = 550, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_550_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_350.parquet"
# INFO: Working on m1 = 600, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_600_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_400.parquet"
# INFO: Working on m1 = 600, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_600_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_100.parquet"
# INFO: Working on m1 = 300, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_300_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_400.parquet"
# INFO: Working on m1 = 150, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_150_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_400.parquet"
# INFO: Working on m1 = 300, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_300_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_50.parquet"
# INFO: Working on m1 = 150, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_150_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_350.parquet"
# INFO: Working on m1 = 200, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_200_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_350.parquet"
# INFO: Working on m1 = 400, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_400_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_150.parquet"
# INFO: Working on m1 = 600, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_600_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_450.parquet"
# INFO: Working on m1 = 150, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_150_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_500.parquet"
# INFO: Working on m1 = 500, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_500_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_150.parquet"
# INFO: Working on m1 = 400, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_400_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_200.parquet"
# INFO: Working on m1 = 500, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_500_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_300.parquet"
# INFO: Working on m1 = 200, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_200_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_250.parquet"
# INFO: Working on m1 = 250, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_250_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_300.parquet"
# INFO: Working on m1 = 300, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_300_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_350.parquet"
# INFO: Working on m1 = 350, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_350_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_550.parquet"
# INFO: Working on m1 = 550, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_550_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_600.parquet"
# INFO: Working on m1 = 300, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_300_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_300.parquet"
# INFO: Working on m1 = 600, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_600_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_250.parquet"
# INFO: Working on m1 = 300, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_300_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_150.parquet"
# INFO: Working on m1 = 100, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_100_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_150.parquet"
# INFO: Working on m1 = 200, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_200_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_500.parquet"
# INFO: Working on m1 = 300, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_300_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_550.parquet"
# INFO: Working on m1 = 400, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_400_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_500.parquet"
# INFO: Working on m1 = 350, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_350_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_50.parquet"
# INFO: Working on m1 = 350, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_350_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_100.parquet"
# INFO: Working on m1 = 100, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_100_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_550.parquet"
# INFO: Working on m1 = 500, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_500_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_550.parquet"
# INFO: Working on m1 = 550, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_550_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_50.parquet"
# INFO: Working on m1 = 550, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_550_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_200.parquet"
# INFO: Working on m1 = 600, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_600_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_550.parquet"
# INFO: Working on m1 = 550, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_550_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_100.parquet"
# INFO: Working on m1 = 450, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_450_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_400.parquet"
# INFO: Working on m1 = 450, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_450_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_150.parquet"
# INFO: Working on m1 = 150, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_150_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_200.parquet"
# INFO: Working on m1 = 100, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_100_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_250.parquet"
# INFO: Working on m1 = 350, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_350_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_600.parquet"
# INFO: Working on m1 = 600, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_600_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_50.parquet"
# INFO: Working on m1 = 200, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_200_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_50.parquet"
# INFO: Working on m1 = 50, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_50_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_150.parquet"
# INFO: Working on m1 = 500, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_500_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_600.parquet"
# INFO: Working on m1 = 450, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_450_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_600.parquet"
# INFO: Working on m1 = 400, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_400_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_300.parquet"
# INFO: Working on m1 = 350, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_350_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_450.parquet"
# INFO: Working on m1 = 300, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_300_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_450.parquet"
# INFO: Working on m1 = 100, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_100_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_400.parquet"
# INFO: Working on m1 = 250, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_250_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_200.parquet"
# INFO: Working on m1 = 100, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_100_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_100.parquet"
# INFO: Working on m1 = 450, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_450_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_500.parquet"
# INFO: Working on m1 = 100, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_100_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_300.parquet"
# INFO: Working on m1 = 200, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_200_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_200_200.parquet"
# INFO: Working on m1 = 450, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_450_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_450.parquet"
# INFO: Working on m1 = 50, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_50_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_450.parquet"
# INFO: Working on m1 = 450, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_450_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_350.parquet"
# INFO: Working on m1 = 600, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_600_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_150.parquet"
# INFO: Working on m1 = 600, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_600_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_500.parquet"
# INFO: Working on m1 = 400, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_400_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_450.parquet"
# INFO: Working on m1 = 50, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_50_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_250.parquet"
# INFO: Working on m1 = 100, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_100_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_350.parquet"
# INFO: Working on m1 = 500, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_500_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_100.parquet"
# INFO: Working on m1 = 550, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_550_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_450.parquet"
# INFO: Working on m1 = 550, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_550_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_400.parquet"
# INFO: Working on m1 = 150, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_150_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_250.parquet"
# INFO: Working on m1 = 250, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_250_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_150.parquet"
# INFO: Working on m1 = 50, m2 = 400
# INFO: Parsing file "LHCO_RnD_qq_50_400.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_400.parquet"
# INFO: Working on m1 = 50, m2 = 300
# INFO: Parsing file "LHCO_RnD_qq_50_300.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_300.parquet"
# INFO: Working on m1 = 550, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_550_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_550.parquet"
# INFO: Working on m1 = 400, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_400_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_600.parquet"
# INFO: Working on m1 = 350, m2 = 500
# INFO: Parsing file "LHCO_RnD_qq_350_500.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_500.parquet"
# INFO: Working on m1 = 100, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_100_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_600.parquet"
# INFO: Working on m1 = 100, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_100_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_100_50.parquet"
# INFO: Working on m1 = 500, m2 = 450
# INFO: Parsing file "LHCO_RnD_qq_500_450.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_450.parquet"
# INFO: Working on m1 = 250, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_250_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_250_100.parquet"
# INFO: Working on m1 = 350, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_350_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_150.parquet"
# INFO: Working on m1 = 400, m2 = 100
# INFO: Parsing file "LHCO_RnD_qq_400_100.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_400_100.parquet"
# INFO: Working on m1 = 550, m2 = 150
# INFO: Parsing file "LHCO_RnD_qq_550_150.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_550_150.parquet"
# INFO: Working on m1 = 600, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_600_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_600_600.parquet"
# INFO: Working on m1 = 50, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_50_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_350.parquet"
# INFO: Working on m1 = 450, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_450_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_550.parquet"
# INFO: Working on m1 = 150, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_150_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_50.parquet"
# INFO: Working on m1 = 350, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_350_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_350_200.parquet"
# INFO: Working on m1 = 500, m2 = 350
# INFO: Parsing file "LHCO_RnD_qq_500_350.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_500_350.parquet"
# INFO: Working on m1 = 300, m2 = 200
# INFO: Parsing file "LHCO_RnD_qq_300_200.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_300_200.parquet"
# INFO: Working on m1 = 50, m2 = 50
# INFO: Parsing file "LHCO_RnD_qq_50_50.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_50.parquet"
# INFO: Working on m1 = 450, m2 = 250
# INFO: Parsing file "LHCO_RnD_qq_450_250.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_450_250.parquet"
# INFO: Working on m1 = 50, m2 = 600
# INFO: Parsing file "LHCO_RnD_qq_50_600.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_50_600.parquet"
# INFO: Working on m1 = 150, m2 = 550
# INFO: Parsing file "LHCO_RnD_qq_150_550.txt"
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/row_based/point_cloud_W_qq_150_550.parquet"

# %%
def get_feature_array(data, njet:int=2):
    array = {}
    for jet_index in range(njet):
        jet_key = f'j{jet_index+1}'
        jet_mask = data['jet_index'] == jet_index
        jet_features = data['jet_features'][jet_mask]
        part_features = data['part_features'][jet_mask]
        array[jet_key] = {}
        # jet features
        array[jet_key]["jet_pt"]   = jet_features[:, 0]
        array[jet_key]["jet_eta"]  = jet_features[:, 1]
        array[jet_key]["jet_phi"]  = jet_features[:, 2]
        array[jet_key]["jet_m"]    = jet_features[:, 3]
        array[jet_key]["jet_btag"] = jet_features[:, 4]
        array[jet_key]["N"]        = ak.count(part_features, axis=-1)
        for i in range(5):
            array[jet_key][f'tau{i+1}'] = jet_features[:, 5 + i]
        tau_mask = ((jet_features[:, 5] > 0) & (jet_features[:, 6] > 0))
        array[jet_key]['tau12'] = np.where(tau_mask, np.divide(jet_features[:, 6],
                                                               jet_features[:, 5], where=tau_mask), 0)
        array[jet_key]['tau23'] = np.where(tau_mask, np.divide(jet_features[:, 7],
                                                               jet_features[:, 6], where=tau_mask), 0)
        jet_p4 = Momentum4DArrayBuilder.get_array_from_dict({
            'pt'  : jet_features[:, 0],
            'eta' : jet_features[:, 1],
            'phi' : jet_features[:, 2],
            'm'   : jet_features[:, 3]})
        # particle features
        array[jet_key]['part_pt']        = part_features.pt
        array[jet_key]['part_eta']       = part_features.eta
        array[jet_key]['part_phi']       = part_features.phi
        array[jet_key]['part_e']         = part_features.e
        array[jet_key]['part_rel_pt']    = part_features.pt / jet_p4.pt
        array[jet_key]['part_delta_eta'] = part_features.deltaeta(jet_p4)
        array[jet_key]['part_delta_phi'] = part_features.deltaphi(jet_p4)
        array[jet_key]['part_delta_R']   = part_features.deltaR(jet_p4)
    ak_array = ak.Array(array)
    return ak_array

# %%
feature_arrays = {}
cache = False
save = True
for masses in data:
    m1, m2 = masses.split("_")
    outname = os.path.join(outdir, "col_based", f"point_cloud_W_qq_{m1}_{m2}.parquet")
    print(f'INFO: Working on m1 = {m1}, m2 = {m2}')
    if (not cache) or (not os.path.exists(outname)):
        print(f'INFO: Converting arrays')
        feature_arrays[masses] = get_feature_array(data[masses], njet=2)
        if save:
            print(f'INFO: Saving output to "{outname}"')
            ak.to_parquet(feature_arrays[masses], outname)
    else:
        print(f'INFO: Cached output from "{outname}"')
        feature_arrays[masses] = ak.from_parquet(outname)
# Out:
# INFO: Working on m1 = 100, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_500.parquet"
# INFO: Working on m1 = 300, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_100.parquet"
# INFO: Working on m1 = 350, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_350.parquet"
# INFO: Working on m1 = 400, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_400.parquet"
# INFO: Working on m1 = 250, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_50.parquet"
# INFO: Working on m1 = 500, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_400.parquet"
# INFO: Working on m1 = 350, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_300.parquet"
# INFO: Working on m1 = 400, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_50.parquet"
# INFO: Working on m1 = 250, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_550.parquet"
# INFO: Working on m1 = 600, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_300.parquet"
# INFO: Working on m1 = 50, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_100.parquet"
# INFO: Working on m1 = 200, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_150.parquet"
# INFO: Working on m1 = 200, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_550.parquet"
# INFO: Working on m1 = 500, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_500.parquet"
# INFO: Working on m1 = 550, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_300.parquet"
# INFO: Working on m1 = 200, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_300.parquet"
# INFO: Working on m1 = 200, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_600.parquet"
# INFO: Working on m1 = 450, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_100.parquet"
# INFO: Working on m1 = 200, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_400.parquet"
# INFO: Working on m1 = 350, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_250.parquet"
# INFO: Working on m1 = 600, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_200.parquet"
# INFO: Working on m1 = 250, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_250.parquet"
# INFO: Working on m1 = 550, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_500.parquet"
# INFO: Working on m1 = 200, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_100.parquet"
# INFO: Working on m1 = 250, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_600.parquet"
# INFO: Working on m1 = 150, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_150.parquet"
# INFO: Working on m1 = 550, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_250.parquet"
# INFO: Working on m1 = 250, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_500.parquet"
# INFO: Working on m1 = 500, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_250.parquet"
# INFO: Working on m1 = 250, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_400.parquet"
# INFO: Working on m1 = 150, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_100.parquet"
# INFO: Working on m1 = 150, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_300.parquet"
# INFO: Working on m1 = 50, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_200.parquet"
# INFO: Working on m1 = 50, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_500.parquet"
# INFO: Working on m1 = 300, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_250.parquet"
# INFO: Working on m1 = 450, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_50.parquet"
# INFO: Working on m1 = 300, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_500.parquet"
# INFO: Working on m1 = 600, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_350.parquet"
# INFO: Working on m1 = 450, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_200.parquet"
# INFO: Working on m1 = 300, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_600.parquet"
# INFO: Working on m1 = 100, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_200.parquet"
# INFO: Working on m1 = 400, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_550.parquet"
# INFO: Working on m1 = 100, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_450.parquet"
# INFO: Working on m1 = 500, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_200.parquet"
# INFO: Working on m1 = 150, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_450.parquet"
# INFO: Working on m1 = 250, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_350.parquet"
# INFO: Working on m1 = 500, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_50.parquet"
# INFO: Working on m1 = 400, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_350.parquet"
# INFO: Working on m1 = 400, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_250.parquet"
# INFO: Working on m1 = 250, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_450.parquet"
# INFO: Working on m1 = 350, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_400.parquet"
# INFO: Working on m1 = 50, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_550.parquet"
# INFO: Working on m1 = 200, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_450.parquet"
# INFO: Working on m1 = 150, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_600.parquet"
# INFO: Working on m1 = 450, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_300.parquet"
# INFO: Working on m1 = 550, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_350.parquet"
# INFO: Working on m1 = 600, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_400.parquet"
# INFO: Working on m1 = 600, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_100.parquet"
# INFO: Working on m1 = 300, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_400.parquet"
# INFO: Working on m1 = 150, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_400.parquet"
# INFO: Working on m1 = 300, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_50.parquet"
# INFO: Working on m1 = 150, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_350.parquet"
# INFO: Working on m1 = 200, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_350.parquet"
# INFO: Working on m1 = 400, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_150.parquet"
# INFO: Working on m1 = 600, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_450.parquet"
# INFO: Working on m1 = 150, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_500.parquet"
# INFO: Working on m1 = 500, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_150.parquet"
# INFO: Working on m1 = 400, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_200.parquet"
# INFO: Working on m1 = 500, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_300.parquet"
# INFO: Working on m1 = 200, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_250.parquet"
# INFO: Working on m1 = 250, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_300.parquet"
# INFO: Working on m1 = 300, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_350.parquet"
# INFO: Working on m1 = 350, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_550.parquet"
# INFO: Working on m1 = 550, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_600.parquet"
# INFO: Working on m1 = 300, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_300.parquet"
# INFO: Working on m1 = 600, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_250.parquet"
# INFO: Working on m1 = 300, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_150.parquet"
# INFO: Working on m1 = 100, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_150.parquet"
# INFO: Working on m1 = 200, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_500.parquet"
# INFO: Working on m1 = 300, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_550.parquet"
# INFO: Working on m1 = 400, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_500.parquet"
# INFO: Working on m1 = 350, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_50.parquet"
# INFO: Working on m1 = 350, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_100.parquet"
# INFO: Working on m1 = 100, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_550.parquet"
# INFO: Working on m1 = 500, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_550.parquet"
# INFO: Working on m1 = 550, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_50.parquet"
# INFO: Working on m1 = 550, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_200.parquet"
# INFO: Working on m1 = 600, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_550.parquet"
# INFO: Working on m1 = 550, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_100.parquet"
# INFO: Working on m1 = 450, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_400.parquet"
# INFO: Working on m1 = 450, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_150.parquet"
# INFO: Working on m1 = 150, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_200.parquet"
# INFO: Working on m1 = 100, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_250.parquet"
# INFO: Working on m1 = 350, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_600.parquet"
# INFO: Working on m1 = 600, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_50.parquet"
# INFO: Working on m1 = 200, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_50.parquet"
# INFO: Working on m1 = 50, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_150.parquet"
# INFO: Working on m1 = 500, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_600.parquet"
# INFO: Working on m1 = 450, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_600.parquet"
# INFO: Working on m1 = 400, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_300.parquet"
# INFO: Working on m1 = 350, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_450.parquet"
# INFO: Working on m1 = 300, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_450.parquet"
# INFO: Working on m1 = 100, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_400.parquet"
# INFO: Working on m1 = 250, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_200.parquet"
# INFO: Working on m1 = 100, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_100.parquet"
# INFO: Working on m1 = 450, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_500.parquet"
# INFO: Working on m1 = 100, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_300.parquet"
# INFO: Working on m1 = 200, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_200_200.parquet"
# INFO: Working on m1 = 450, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_450.parquet"
# INFO: Working on m1 = 50, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_450.parquet"
# INFO: Working on m1 = 450, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_350.parquet"
# INFO: Working on m1 = 600, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_150.parquet"
# INFO: Working on m1 = 600, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_500.parquet"
# INFO: Working on m1 = 400, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_450.parquet"
# INFO: Working on m1 = 50, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_250.parquet"
# INFO: Working on m1 = 100, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_350.parquet"
# INFO: Working on m1 = 500, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_100.parquet"
# INFO: Working on m1 = 550, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_450.parquet"
# INFO: Working on m1 = 550, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_400.parquet"
# INFO: Working on m1 = 150, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_250.parquet"
# INFO: Working on m1 = 250, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_150.parquet"
# INFO: Working on m1 = 50, m2 = 400
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_400.parquet"
# INFO: Working on m1 = 50, m2 = 300
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_300.parquet"
# INFO: Working on m1 = 550, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_550.parquet"
# INFO: Working on m1 = 400, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_600.parquet"
# INFO: Working on m1 = 350, m2 = 500
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_500.parquet"
# INFO: Working on m1 = 100, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_600.parquet"
# INFO: Working on m1 = 100, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_100_50.parquet"
# INFO: Working on m1 = 500, m2 = 450
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_450.parquet"
# INFO: Working on m1 = 250, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_250_100.parquet"
# INFO: Working on m1 = 350, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_150.parquet"
# INFO: Working on m1 = 400, m2 = 100
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_400_100.parquet"
# INFO: Working on m1 = 550, m2 = 150
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_550_150.parquet"
# INFO: Working on m1 = 600, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_600_600.parquet"
# INFO: Working on m1 = 50, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_350.parquet"
# INFO: Working on m1 = 450, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_550.parquet"
# INFO: Working on m1 = 150, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_50.parquet"
# INFO: Working on m1 = 350, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_350_200.parquet"
# INFO: Working on m1 = 500, m2 = 350
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_500_350.parquet"
# INFO: Working on m1 = 300, m2 = 200
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_300_200.parquet"
# INFO: Working on m1 = 50, m2 = 50
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_50.parquet"
# INFO: Working on m1 = 450, m2 = 250
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_450_250.parquet"
# INFO: Working on m1 = 50, m2 = 600
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_50_600.parquet"
# INFO: Working on m1 = 150, m2 = 550
# INFO: Converting arrays
# INFO: Saving output to "/pscratch/sd/c/chlcheng/dataset/anomaly_detection/LHC_Olympics_2020/LHCO_RnD_qq/col_based/point_cloud_W_qq_150_550.parquet"

# %%
import pandas as pd
from quickstats.plots import VariableDistributionPlot
dfs = {}
for masses in ["100_500", "350_350", "550_50"]:
    data = {
        "lead_jet_pt"    : np.array(feature_arrays[masses]["j1"]["jet_pt"]),
        "lead_jet_eta"   : np.array(feature_arrays[masses]["j1"]["jet_eta"]),
        "lead_jet_phi"   : np.array(feature_arrays[masses]["j1"]["jet_phi"]),
        "lead_jet_m"     : np.array(feature_arrays[masses]["j1"]["jet_m"]),
        "lead_jet_N"     : np.array(feature_arrays[masses]["j1"]["N"]),
        "lead_jet_tau1"  : np.array(feature_arrays[masses]["j1"]["tau1"]),
        "lead_jet_tau2"  : np.array(feature_arrays[masses]["j1"]["tau2"]),
        "lead_jet_tau3"  : np.array(feature_arrays[masses]["j1"]["tau3"]),
        "lead_jet_tau12" : np.array(feature_arrays[masses]["j1"]["tau12"]),
        "lead_jet_tau23" : np.array(feature_arrays[masses]["j1"]["tau23"]),
        "sub_jet_pt"     : np.array(feature_arrays[masses]["j2"]["jet_pt"]),
        "sub_jet_eta"    : np.array(feature_arrays[masses]["j2"]["jet_eta"]),
        "sub_jet_phi"    : np.array(feature_arrays[masses]["j2"]["jet_phi"]),
        "sub_jet_m"      : np.array(feature_arrays[masses]["j2"]["jet_m"]),
        "sub_jet_N"      : np.array(feature_arrays[masses]["j2"]["N"]),
        "sub_jet_tau1"   : np.array(feature_arrays[masses]["j2"]["tau1"]),
        "sub_jet_tau2"   : np.array(feature_arrays[masses]["j2"]["tau2"]),
        "sub_jet_tau3"   : np.array(feature_arrays[masses]["j2"]["tau3"]),
        "sub_jet_tau12"  : np.array(feature_arrays[masses]["j2"]["tau12"]),
        "sub_jet_tau23"  : np.array(feature_arrays[masses]["j2"]["tau23"])
    }
    # calculate mjj
    j1_p4 = ak.zip({
    "pt"  : feature_arrays[masses]["j1"]["jet_pt"],
    "eta" : feature_arrays[masses]["j1"]["jet_eta"],
    "phi" : feature_arrays[masses]["j1"]["jet_phi"],
    "m"   : feature_arrays[masses]["j1"]["jet_m"]
    }, with_name="Momentum4D")
    j2_p4 = ak.zip({
        "pt"  : feature_arrays[masses]["j2"]["jet_pt"],
        "eta" : feature_arrays[masses]["j2"]["jet_eta"],
        "phi" : feature_arrays[masses]["j2"]["jet_phi"],
        "m"   : feature_arrays[masses]["j2"]["jet_m"]
    }, with_name="Momentum4D")
    jj_p4 = j1_p4.add(j2_p4)
    data['mjj'] = np.array(jj_p4.m)
    dfs[masses] = pd.DataFrame(data)

# %%
from quickstats.plots import VariableDistributionPlot
import matplotlib.pyplot as plt
options = {
    'mjj': {
        'xlabel': '$m_{jj} [GeV]$',
        'bin_range': (2000, 5000)
    },
    'lead_jet_pt': {
        'xlabel': '$p_T^{j_1} [GeV]$',
        'bin_range': (1200, 2600)
    },
    'sub_jet_pt': {
        'xlabel': '$p_T^{j_2} [GeV]$',
        'bin_range': (1200, 2600)
    },
    'lead_jet_m': {
        'xlabel': '$m^{j_1} [GeV]$',
        'bin_range': (0, 800)
    },
    'sub_jet_m': {
        'xlabel': '$m^{j_2} [GeV]$',
        'bin_range': (0, 800)
    },
    'lead_jet_eta': {
        'xlabel': r'$\eta_{j_1}$'
    },
    'sub_jet_eta': {
        'xlabel': r'$\eta_{j_2}$'
    },
    'lead_jet_phi': {
        'xlabel': r'$\phi_{j_1}$'
    },
    'sub_jet_phi': {
        'xlabel': r'$\phi_{j_2}$'
    },
    'lead_jet_N': {
        'xlabel': '$N_{particle}^{j_1}$'
    },
    'sub_jet_N': {
        'xlabel': '$N_{particle}^{j_2}$'
    },
    'lead_jet_tau1': {
        'xlabel': r'$\tau_1^{j_1}$'
    },
    'sub_jet_tau1': {
        'xlabel': r'$\tau_1^{j_2}$'
    },
    'lead_jet_tau2': {
        'xlabel': r'$\tau_2^{j_1}$'
    },
    'sub_jet_tau2': {
        'xlabel': r'$\tau_2^{j_2}$'
    },
    'lead_jet_tau3': {
        'xlabel': r'$\tau_3^{j_1}$'
    },
    'sub_jet_tau3': {
        'xlabel': r'$\tau_3^{j_2}$'
    },
    'lead_jet_tau12': {
        'xlabel': r'$\tau_2^{j_1}/\tau_1^{j_1}$'
    },
    'sub_jet_tau12': {
        'xlabel': r'$\tau_2^{j_2}/\tau_1^{j_2}$'
    },
    'lead_jet_tau23': {
        'xlabel': r'$\tau_3^{j_1}/\tau_2^{j_1}$'
    },
    'sub_jet_tau23': {
        'xlabel': r'$\tau_3^{j_2}/\tau_2^{j_2}$'
    }
}
label_map = {
    '100_500' : 'm1 = 100 GeV, m2 = 500 GeV',
    '350_350' : 'm1 = 350 GeV, m2 = 350 GeV',
    '550_50'  : 'm1 = 550 GeV, m2 = 50 GeV'
}
plotter = VariableDistributionPlot(dfs, label_map=label_map)
for column in options:
    plotter.draw(column,
                 **options[column],
                 bins=50,
                 normalize=True,
                 ypad=0.1)
    plt.show()
# Out:
# [INFO] Using deduced bin range (-3.042, 2.641)
# [INFO] Using deduced bin range (-4.863, 4.640)
# [INFO] Using deduced bin range (-3.142, 3.142)
# [INFO] Using deduced bin range (-3.142, 3.142)
# [INFO] Using deduced bin range (0.000, 97.000)
# [INFO] Using deduced bin range (0.000, 82.000)
# [INFO] Using deduced bin range (0.002, 0.718)
# [INFO] Using deduced bin range (0.000, 0.649)
# [INFO] Using deduced bin range (0.001, 0.396)
# [INFO] Using deduced bin range (0.000, 0.452)
# [INFO] Using deduced bin range (0.000, 0.215)
# [INFO] Using deduced bin range (0.000, 0.297)
# [INFO] Using deduced bin range (0.014, 0.905)
# [INFO] Using deduced bin range (0.000, 0.904)
# [INFO] Using deduced bin range (0.071, 0.947)
# [INFO] Using deduced bin range (0.000, 0.947)
